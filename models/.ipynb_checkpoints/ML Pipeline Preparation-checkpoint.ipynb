# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pickle

import re
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, f1_score, fbeta_score, classification_report
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

from scipy.stats import hmean
from scipy.stats.mstats import gmean

nltk.download(['punkt', 'wordnet', 'averaged_perceptron_tagger'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\usamnet\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\usamnet\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\usamnet\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# load data from database
engine = create_engine('sqlite:///'+"..\\data\\"+'DisasterResponse.db')
df = pd.read_sql_query('SELECT * FROM merged', engine)
#df = pd.read_sql_table('merged',engine)
X = df['message']
Y = df.iloc[:,4:]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
class StartingVerbExtractor(BaseEstimator, TransformerMixin):

    def starting_verb(self, text):
        sentence_list = nltk.sent_tokenize(text)
        for sentence in sentence_list:
            pos_tags = nltk.pos_tag(tokenize(sentence))
            first_word, first_tag = pos_tags[0]
            if first_tag in ['VB', 'VBP'] or first_word == 'RT':
                return True
        return False

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_tagged = pd.Series(X).apply(self.starting_verb)
        return pd.DataFrame(X_tagged)

# %%
def build_model():
    """

    return: pipeline modal after applying pipeline
    """
    pipeline = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('vect', CountVectorizer(tokenizer=tokenize)),
                ('tfidf', TfidfTransformer())
            ])),

            ('starting_verb', StartingVerbExtractor())
        ])),

        ('clf', MultiOutputClassifier(RandomForestClassifier()))
    ])

    return pipeline

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
import warnings
warnings.filterwarnings("ignore")
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

model = build_model()
model.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('features',
#                                         FeatureUnion(n_jobs=None,
#                                                      transformer_list=[('text_pipeline',
#                                                                         Pipeline(memory=None,
#                                                                                  steps=[('vect',
#                                                                                          CountVectorizer(analyzer='word',
#                                                                                                          binary=False,
#                                                                                                          decode_error='strict',
#                                                                                                          dtype=<class 'numpy.int64'>,
#                                                                                                          encoding='utf-8',
#                                                                                                          input='content',
#                                                                                                          lowercase=True,
#                                                                                                          max_df=...
#                                                                         StartingVerbExtractor())],
#                                                      transformer_weights=None,
#                                                      verbose=False)),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=AdaBoostClassifier(algorithm='SAMME.R',
#                                                                                            base_estimator=None,
#                                                                                            learning_rate=1.0,
#                                                                                            n_estimators=50,
#                                                                                            random_state=None),
#                                                               n_jobs=None))],
#                                 verbose=False),
#              iid='warn', n_jobs=None, param_grid={}, pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring=None, verbose=0)

# %% [markdown]
# Let's see is the model tells us something reasonable!

# %%
msg = ['sentences can be helpful in a number of different ways']
test_output = model.predict(msg)
print(Y_train.columns.values[(test_output.flatten()==1)])
# Out:
# ['related' 'water']

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
def multioutput_fscore(y_true,y_pred,beta=1):
    score_list = []
    if isinstance(y_pred, pd.DataFrame) == True:
        y_pred = y_pred.values
    if isinstance(y_true, pd.DataFrame) == True:
        y_true = y_true.values
    for column in range(0,y_true.shape[1]):
        score = fbeta_score(y_true[:,column],y_pred[:,column],beta,average='weighted')
        score_list.append(score)
    f1score_numpy = np.asarray(score_list)
    f1score_numpy = f1score_numpy[f1score_numpy<1]
    f1score = gmean(f1score_numpy)
    return  f1score

# %%
Y_pred = model.predict(X_test)
multi_f1 = multioutput_fscore(Y_test,Y_pred, beta = 1)
overall_accuracy = (Y_pred == Y_test).mean().mean()

print('Average overall accuracy {0:.2f}% \n'.format(overall_accuracy*100))
print('f1 score (custom definition) {0:.2f}%\n'.format(multi_f1*100))
# Out:
# Average overall accuracy 92.60%
#
# f1 score (custom definition) 89.25%

# %%
Y_pred_pd = pd.DataFrame(Y_pred, columns = Y_test.columns)
for column in Y_test.columns:
    print('#####################################################\n')
    print('FEATURE: {}\n'.format(column))
    print(classification_report(Y_test[column],Y_pred_pd[column]))
# Out:
# #####################################################
#
# FEATURE: genre_news
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      3248
#            1       0.98      0.92      0.95      3247
#
#     accuracy                           0.95      6495
#    macro avg       0.95      0.95      0.95      6495
# weighted avg       0.95      0.95      0.95      6495
#
# #####################################################
#
# FEATURE: genre_social
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      5878
#            1       0.98      0.74      0.84       617
#
#     accuracy                           0.97      6495
#    macro avg       0.98      0.87      0.91      6495
# weighted avg       0.97      0.97      0.97      6495
#
# #####################################################
#
# FEATURE: related
#
#               precision    recall  f1-score   support
#
#            0       0.31      0.12      0.17      1525
#            1       0.77      0.92      0.84      4926
#            2       0.09      0.02      0.04        44
#
#     accuracy                           0.73      6495
#    macro avg       0.39      0.35      0.35      6495
# weighted avg       0.66      0.73      0.67      6495
#
# #####################################################
#
# FEATURE: request
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90      5391
#            1       0.34      0.04      0.08      1104
#
#     accuracy                           0.82      6495
#    macro avg       0.59      0.51      0.49      6495
# weighted avg       0.75      0.82      0.76      6495
#
# #####################################################
#
# FEATURE: offer
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6466
#            1       0.00      0.00      0.00        29
#
#     accuracy                           1.00      6495
#    macro avg       0.50      0.50      0.50      6495
# weighted avg       0.99      1.00      0.99      6495
#
# #####################################################
#
# FEATURE: aid_related
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.84      0.70      3818
#            1       0.45      0.19      0.26      2677
#
#     accuracy                           0.57      6495
#    macro avg       0.52      0.51      0.48      6495
# weighted avg       0.53      0.57      0.52      6495
#
# #####################################################
#
# FEATURE: medical_help
#
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      5979
#            1       0.05      0.00      0.00       516
#
#     accuracy                           0.92      6495
#    macro avg       0.49      0.50      0.48      6495
# weighted avg       0.85      0.92      0.88      6495
#
# #####################################################
#
# FEATURE: medical_products
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      6186
#            1       0.00      0.00      0.00       309
#
#     accuracy                           0.95      6495
#    macro avg       0.48      0.50      0.49      6495
# weighted avg       0.91      0.95      0.93      6495
#
# #####################################################
#
# FEATURE: search_and_rescue
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6322
#            1       0.00      0.00      0.00       173
#
#     accuracy                           0.97      6495
#    macro avg       0.49      0.50      0.49      6495
# weighted avg       0.95      0.97      0.96      6495
#
# #####################################################
#
# FEATURE: security
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6379
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.98      6495
#    macro avg       0.49      0.50      0.50      6495
# weighted avg       0.96      0.98      0.97      6495
#
# #####################################################
#
# FEATURE: military
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6281
#            1       0.00      0.00      0.00       214
#
#     accuracy                           0.97      6495
#    macro avg       0.48      0.50      0.49      6495
# weighted avg       0.94      0.97      0.95      6495
#
# #####################################################
#
# FEATURE: child_alone
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6495
#
#     accuracy                           1.00      6495
#    macro avg       1.00      1.00      1.00      6495
# weighted avg       1.00      1.00      1.00      6495
#
# #####################################################
#
# FEATURE: water
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6115
#            1       0.06      0.01      0.01       380
#
#     accuracy                           0.94      6495
#    macro avg       0.50      0.50      0.49      6495
# weighted avg       0.89      0.94      0.91      6495
#
# #####################################################
#
# FEATURE: food
#
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      5794
#            1       0.10      0.00      0.01       701
#
#     accuracy                           0.89      6495
#    macro avg       0.50      0.50      0.47      6495
# weighted avg       0.81      0.89      0.84      6495
#
# #####################################################
#
# FEATURE: shelter
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      5955
#            1       0.03      0.00      0.00       540
#
#     accuracy                           0.91      6495
#    macro avg       0.47      0.50      0.48      6495
# weighted avg       0.84      0.91      0.87      6495
#
# #####################################################
#
# FEATURE: clothing
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6401
#            1       0.00      0.00      0.00        94
#
#     accuracy                           0.99      6495
#    macro avg       0.49      0.50      0.50      6495
# weighted avg       0.97      0.99      0.98      6495
#
# #####################################################
#
# FEATURE: money
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6363
#            1       0.00      0.00      0.00       132
#
#     accuracy                           0.98      6495
#    macro avg       0.49      0.50      0.49      6495
# weighted avg       0.96      0.98      0.97      6495
#
# #####################################################
#
# FEATURE: missing_people
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6419
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.99      6495
#    macro avg       0.49      0.50      0.50      6495
# weighted avg       0.98      0.99      0.98      6495
#
# #####################################################
#
# FEATURE: refugees
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6261
#            1       0.00      0.00      0.00       234
#
#     accuracy                           0.96      6495
#    macro avg       0.48      0.50      0.49      6495
# weighted avg       0.93      0.96      0.95      6495
#
# #####################################################
#
# FEATURE: death
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6214
#            1       0.00      0.00      0.00       281
#
#     accuracy                           0.96      6495
#    macro avg       0.48      0.50      0.49      6495
# weighted avg       0.92      0.96      0.93      6495
#
# #####################################################
#
# FEATURE: other_aid
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92      5633
#            1       0.10      0.01      0.01       862
#
#     accuracy                           0.86      6495
#    macro avg       0.48      0.50      0.47      6495
# weighted avg       0.77      0.86      0.80      6495
#
# #####################################################
#
# FEATURE: infrastructure_related
#
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      6062
#            1       0.00      0.00      0.00       433
#
#     accuracy                           0.93      6495
#    macro avg       0.47      0.50      0.48      6495
# weighted avg       0.87      0.93      0.90      6495
#
# #####################################################
#
# FEATURE: transport
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6202
#            1       0.00      0.00      0.00       293
#
#     accuracy                           0.95      6495
#    macro avg       0.48      0.50      0.49      6495
# weighted avg       0.91      0.95      0.93      6495
#
# #####################################################
#
# FEATURE: buildings
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      6131
#            1       0.03      0.00      0.01       364
#
#     accuracy                           0.94      6495
#    macro avg       0.49      0.50      0.49      6495
# weighted avg       0.89      0.94      0.91      6495
#
# #####################################################
#
# FEATURE: electricity
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6362
#            1       0.00      0.00      0.00       133
#
#     accuracy                           0.98      6495
#    macro avg       0.49      0.50      0.49      6495
# weighted avg       0.96      0.98      0.97      6495
#
# #####################################################
#
# FEATURE: tools
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6464
#            1       0.00      0.00      0.00        31
#
#     accuracy                           1.00      6495
#    macro avg       0.50      0.50      0.50      6495
# weighted avg       0.99      1.00      0.99      6495
#
# #####################################################
#
# FEATURE: hospitals
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6417
#            1       0.00      0.00      0.00        78
#
#     accuracy                           0.99      6495
#    macro avg       0.49      0.50      0.50      6495
# weighted avg       0.98      0.99      0.98      6495
#
# #####################################################
#
# FEATURE: shops
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6466
#            1       0.00      0.00      0.00        29
#
#     accuracy                           1.00      6495
#    macro avg       0.50      0.50      0.50      6495
# weighted avg       0.99      1.00      0.99      6495
#
# #####################################################
#
# FEATURE: aid_centers
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6413
#            1       0.00      0.00      0.00        82
#
#     accuracy                           0.99      6495
#    macro avg       0.49      0.50      0.50      6495
# weighted avg       0.97      0.99      0.98      6495
#
# #####################################################
#
# FEATURE: other_infrastructure
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6215
#            1       0.10      0.00      0.01       280
#
#     accuracy                           0.96      6495
#    macro avg       0.53      0.50      0.49      6495
# weighted avg       0.92      0.96      0.94      6495
#
# #####################################################
#
# FEATURE: weather_related
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.95      0.83      4684
#            1       0.53      0.14      0.22      1811
#
#     accuracy                           0.72      6495
#    macro avg       0.63      0.54      0.53      6495
# weighted avg       0.68      0.72      0.66      6495
#
# #####################################################
#
# FEATURE: floods
#
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      5974
#            1       0.07      0.00      0.00       521
#
#     accuracy                           0.92      6495
#    macro avg       0.49      0.50      0.48      6495
# weighted avg       0.85      0.92      0.88      6495
#
# #####################################################
#
# FEATURE: storm
#
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      5854
#            1       0.40      0.03      0.06       641
#
#     accuracy                           0.90      6495
#    macro avg       0.65      0.51      0.50      6495
# weighted avg       0.85      0.90      0.86      6495
#
# #####################################################
#
# FEATURE: fire
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6426
#            1       0.00      0.00      0.00        69
#
#     accuracy                           0.99      6495
#    macro avg       0.49      0.50      0.50      6495
# weighted avg       0.98      0.99      0.98      6495
#
# #####################################################
#
# FEATURE: earthquake
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      5904
#            1       0.64      0.13      0.21       591
#
#     accuracy                           0.91      6495
#    macro avg       0.78      0.56      0.58      6495
# weighted avg       0.89      0.91      0.89      6495
#
# #####################################################
#
# FEATURE: cold
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6375
#            1       0.00      0.00      0.00       120
#
#     accuracy                           0.98      6495
#    macro avg       0.49      0.50      0.50      6495
# weighted avg       0.96      0.98      0.97      6495
#
# #####################################################
#
# FEATURE: other_weather
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6146
#            1       0.00      0.00      0.00       349
#
#     accuracy                           0.95      6495
#    macro avg       0.47      0.50      0.49      6495
# weighted avg       0.90      0.95      0.92      6495
#
# #####################################################
#
# FEATURE: direct_report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89      5261
#            1       0.33      0.05      0.09      1234
#
#     accuracy                           0.80      6495
#    macro avg       0.57      0.51      0.49      6495
# weighted avg       0.72      0.80      0.74      6495

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %% [markdown]
# - Add Custom Estimator StartingVerbExtractor
# - Add Other Machine Learning Algorithms AdaBoostClassifier
# - Improve Model Pipeline With GridSearchCV

# %%
# Optimize the function using GridSearchCV
def build_model():
    """

    :return: model after applying pipeline
    """
    pipeline = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('vect', CountVectorizer(tokenizer=tokenize)),
                ('tfidf', TfidfTransformer())
            ])),

            ('starting_verb', StartingVerbExtractor())
        ])),

        ('clf', MultiOutputClassifier(AdaBoostClassifier()))
    ])

    parameters = {
    #'features__text_pipeline__vect__ngram_range': ((1, 1), (1, 2)),
    #'features__text_pipeline__vect__max_df': (0.75, 1.0),
    #'features__text_pipeline__vect__max_features': (None, 5000),
    #'features__text_pipeline__tfidf__use_idf': (True, False),
    }

    cv = GridSearchCV(pipeline, param_grid=parameters)

    return cv

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
Y_pred = model.predict(X_test)
multi_f1 = multioutput_fscore(Y_test,Y_pred, beta = 1)
overall_accuracy = (Y_pred == Y_test).mean().mean()

print('Average overall accuracy {0:.2f}% \n'.format(overall_accuracy*100))
print('f1 score (custom definition) {0:.2f}%\n'.format(multi_f1*100))
# Out:
# Average overall accuracy 92.75%
#
# f1 score (custom definition) 89.11%

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# The use of another algorithm As AdaBoostClassifier instead of RandomForest improves accuracy by
#
# 1) Overall accuracy: from 92.60% to 92.75%
#
# 2) Customized multi-class multi-label f1-score: from 89.25% to 89.11%
#
# Add New feaure (first verb), It gives the possibility to add an additional feature to the prediction in experience
#
# > **note**
# The process takes a lot of time with the addition of a parameter so the results are very close
# The addition of the parameter was ignored at the present time, but the parameter could have been added and if you added the parameter to improve the performance of the model, but unfortunately a device takes a long time to complete this process

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
# save the model to disk
with open('classifier.pkl', 'wb') as file:
    pickle.dump(model, file)

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
